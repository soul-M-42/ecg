# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import scipy.io as scio
import numpy as np
import random
import torch.utils.data as data
import os
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from tqdm import tqdm
from glob import glob

# %%
# In this section, we will apply an CNN to extract features and implement a classification task.
# Firstly, we should build the model by PyTorch. We provide a baseline model here.
# You can use your own model for better performance
class Doubleconv_33(nn.Module):
    def __init__(self, ch_in, ch_out):
        super(Doubleconv_33, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(ch_in, ch_out, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.Conv1d(ch_out, ch_out, kernel_size=3),
            nn.ReLU(inplace=True)
        )

    def forward(self, input):
        return self.conv(input)


class Doubleconv_35(nn.Module):
    def __init__(self, ch_in, ch_out):
        super(Doubleconv_35, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(ch_in, ch_out, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.Conv1d(ch_out, ch_out, kernel_size=5),
            nn.ReLU(inplace=True)
        )

    def forward(self, input):
        return self.conv(input)


class Doubleconv_37(nn.Module):
    def __init__(self, ch_in, ch_out):
        super(Doubleconv_37, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(ch_in, ch_out, kernel_size=7),
            nn.ReLU(inplace=True),
            nn.Conv1d(ch_out, ch_out, kernel_size=7),
            nn.ReLU(inplace=True)
        )

    def forward(self, input):
        return self.conv(input)


class Tripleconv(nn.Module):
    def __init__(self, ch_in, ch_out):
        super(Tripleconv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(ch_in, ch_out, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.Conv1d(ch_out, ch_out, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.Conv1d(ch_out, ch_out, kernel_size=3),
            nn.ReLU(inplace=True)
        )

    def forward(self, input):
        return self.conv(input)

class MLP(nn.Module):
    def __init__(self, ch_in, ch_out):
        super(MLP, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(ch_in, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True),
            nn.Linear(1024, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True),
            nn.Linear(1024, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(inplace=True),
            nn.Linear(256, ch_out),
        )

    def forward(self, input):
        return self.fc(input)


class Mscnn(nn.Module):
    # TODO: Build a better model
    def __init__(self, ch_in, ch_out):
        super(Mscnn, self).__init__()
        self.conv11 = Doubleconv_33(ch_in, 64)
        self.pool11 = nn.MaxPool1d(3, stride=3)
        self.conv12 = Doubleconv_33(64, 128)
        self.pool12 = nn.MaxPool1d(3, stride=3)
        self.conv13 = Tripleconv(128, 256)
        self.pool13 = nn.MaxPool1d(2, stride=2)
        self.conv14 = Tripleconv(256, 512)
        self.pool14 = nn.MaxPool1d(2, stride=2)
        self.conv15 = Tripleconv(512, 512)
        self.pool15 = nn.MaxPool1d(2, stride=2)

        self.out = MLP(512*27, ch_out)  

    def forward(self, x):
        c11 = self.conv11(x)
        p11 = self.pool11(c11)
        c12 = self.conv12(p11)
        p12 = self.pool12(c12)
        c13 = self.conv13(p12)
        p13 = self.pool13(c13)
        c14 = self.conv14(p13)
        p14 = self.pool14(c14)
        c15 = self.conv15(p14)
        p15 = self.pool15(c15)
        merge = p15.view(p15.size()[0], -1) 
        output = self.out(merge)
        output = F.sigmoid(output)
        return output

# %%
# Next, we need to construct the data loader for training. 
import numpy as np
import pandas as pd
from torch.utils.data import Dataset
import scipy.io as io
import torch
import matplotlib.pyplot as plt 

# Random clipping has been implemented, 
# and you need to add noise and random scaling. 
# Generally, the scaling should be done before the crop.
# In general, do not add scaling and noise enhancement options during testing

class ECG_dataset(Dataset):

    def __init__(self,base_file,cv=0, is_train=True):

        self.is_train = is_train
        self.file_list=[]
        self.base_file=base_file
        
        for i in range(5):
            data=pd.read_csv(base_file+'/cv/cv'+str(i)+'.csv')
            self.file_list.append(data.to_numpy())
        self.file=None
        if is_train:
            del self.file_list[cv]
            self.file=self.file_list[0]
            for i in range(1,4):
                self.file=np.append(self.file,self.file_list[i],axis=0)
        else:
            self.file=self.file_list[cv]

        
    def __len__(self):
        return self.file.shape[0]
    

    def load_data(self,file_name,label):
        #读取数据
        mat_file = self.base_file+'/training2017/'+file_name+'.mat'
        data = io.loadmat(mat_file)['val']
        if label=='N':
            one_hot=torch.tensor([0])
        elif label=='O':
            one_hot=torch.tensor([0])
        elif label=='A':
            one_hot=torch.tensor([1])
        elif label=='~':
            one_hot=torch.tensor([0])
        return data,one_hot


    
    def crop_padding(self,data,time):
        #随机crop
        if data.shape[0]<=time:
            data=np.pad(data, (0,time-data.shape[0]), 'constant')
        elif data.shape[0]>time:
            end_index=data.shape[0]-time
            start=np.random.randint(0, end_index)
            data=data[start:start+time]
        return data



    def data_process(self,data):
        # 学习论文以及数据集选择合适和采样率
        # 并完成随机gaussian 噪声和随机时间尺度放缩
        data=data[::3]
        data=data-data.mean()
        data=data/data.std()
        data=self.crop_padding(data,2400)
        data=torch.tensor(data)
        return data


    def __getitem__(self, idx):
        file_name=self.file[idx][1]
        label=self.file[idx][2]
        data,one_hot=self.load_data(file_name,label)
        data=self.data_process(data[0]).unsqueeze(0).float()
        one_hot=one_hot.unsqueeze(0).float()
        return data, one_hot,file_name

# %%
# Now, we will build the pipeline for deep learning based training.
# These functions may be useful :)
def save_loss(fold, value):
    path = 'loss' + str(fold) + '.txt'
    file = open(path, mode='a+')
    file.write(str(value)+'\n')  
    
# We will use GPU if cuda is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Mscnn(1, 1).to(device)   # ch_in, ch_out

# Build pre-processing transformation 
# Note this pre-processing is in PyTorch
x_transforms = transforms.Compose([
        transforms.ToTensor(),  
])
y_transforms = transforms.ToTensor()


# TODO: fine tune hyper-parameters
batch_size = 64
criterion = torch.nn.MSELoss()
criterion2=torch.nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
train_ecg_dataset = ECG_dataset('/raid5/pangyj/ecg', is_train=True)
train_dataloader = DataLoader(train_ecg_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
test_ecg_dataset = ECG_dataset('/raid5/pangyj/ecg', is_train=False)
test_dataloaders = DataLoader(test_ecg_dataset, batch_size=1)
num_epochs = 10

# %%
from sklearn.metrics import accuracy_score

def validation(model,criterion,test_dataloaders,device):
    # TODO: add more metrics for evaluation?
    # Evaluate 
    model.eval()
    predict = np.array([])
    target = np.array([])
    loss=0
    step=0
    with torch.no_grad():
        for x, mask,name in test_dataloaders:
            step += 1
            mask=mask.to(device)
            y = model(x.to(device))
            loss +=criterion(y, mask.squeeze(2)).item()
            y[y >= 0.5] = 1
            y[y < 0.5] = 0
            predict=np.append(predict,torch.squeeze(y).cpu().numpy())
            target=np.append(target,torch.squeeze(mask).cpu().numpy())
    acc = accuracy_score(target, predict)
    print('Accuracy: {}'.format(acc))
    print('Loss:', loss/step)
    model.train()




# Start training !
for epoch in range(1, num_epochs + 1):
        predict = np.array([])
        target = np.array([])
        print('Epoch {}/{}'.format(epoch, num_epochs))
        dt_size = len(train_dataloader.dataset)
        epoch_loss = 0
        step = 0
        process = tqdm(train_dataloader)
        for x, y,name in process:
            step += 1
            inputs = x.to(device)
            labels = y.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion2(outputs, labels.squeeze(2))
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            process.set_description(
                "epoch: %d, train_loss:%0.8f" % (epoch, epoch_loss / step)
            )
            outputs[outputs >= 0.5] = 1
            outputs[outputs < 0.5] = 0
            predict=np.append(predict,torch.squeeze(outputs).detach().cpu().numpy())
            target=np.append(target,torch.squeeze(labels).detach().cpu().numpy())
        epoch_loss /= step
        acc = accuracy_score(target, predict)
        print('tran_Accuracy: {}'.format(acc))
        save_loss(10, epoch_loss)
        validation(model,criterion2,test_dataloaders,device)
# Save model
torch.save(model.state_dict(), 'weights10_%d.pth' % (epoch))
# Out:
# Epoch 1/10
#   0%|          | 0/107 [00:00<?, ?it/s]/raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# epoch: 1, train_loss:0.31440030: 100%|██████████| 107/107 [00:07<00:00, 13.62it/s]
# /raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# tran_Accuracy: 0.8985634711228379
# tensor([[0.0666]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1004]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0495]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2205]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1392]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1138]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1578]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0546]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0441]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0517]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2095]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2212]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0466]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2403]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0655]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2290]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2160]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0529]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2113]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1241]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.2223]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.2261]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1977]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2211]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2266]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0425]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1848]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2063]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.2302]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1052]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0691]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0801]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2220]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1181]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2121]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2085]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2253]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1644]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2031]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0607]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0523]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1872]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2295]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0768]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2331]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1995]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2222]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1584]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1004]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0477]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2135]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2266]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2274]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1048]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2064]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2109]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2145]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2252]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2298]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1120]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0491]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1386]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.2226]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2154]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2076]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2199]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0784]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0476]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0438]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0754]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2160]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0401]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0524]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1920]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2040]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1620]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.2420]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0435]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2332]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2105]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0866]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0560]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.1325]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1067]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2007]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# Accuracy: 0.910850439882698
# Loss: 0.31876569237352465
# Epoch 2/10
#   0%|          | 0/107 [00:00<?, ?it/s]/raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# epoch: 2, train_loss:0.25622281: 100%|██████████| 107/107 [00:07<00:00, 13.82it/s]
# /raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# tran_Accuracy: 0.9142480211081794
# tensor([[0.0592]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.5523]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1472]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0705]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.3895]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.5724]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0904]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2482]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2056]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2225]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2566]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0087]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.3235]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0464]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.8598]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.3022]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0221]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.3501]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.5303]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.4637]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.9006]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.8430]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0750]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0414]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.7039]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0099]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0312]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.5946]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.1333]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2282]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1477]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2711]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0112]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1264]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0261]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.7622]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0813]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.4585]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1968]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.4580]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2614]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.4157]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0373]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0495]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2462]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.5214]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1953]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0218]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.4979]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1356]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0053]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0132]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0497]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0474]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0321]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2635]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.4696]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0122]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2047]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.5019]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0794]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.7184]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.4165]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.6531]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0746]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.4540]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0857]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.3156]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1261]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0385]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0224]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0211]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.5327]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0180]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0276]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.5133]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.5569]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2265]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0536]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2063]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1116]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.3596]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.3686]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1655]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0253]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# Accuracy: 0.8762463343108504
# Loss: 0.3237769371971947
# Epoch 3/10
#   0%|          | 0/107 [00:00<?, ?it/s]/raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# epoch: 3, train_loss:0.19612967: 100%|██████████| 107/107 [00:07<00:00, 13.74it/s]
# /raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# tran_Accuracy: 0.9221635883905013
# tensor([[0.0044]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0247]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0035]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0030]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0022]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0657]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0052]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0081]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0051]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0178]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0023]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0005]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0033]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0004]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2852]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0068]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0007]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0104]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0189]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0484]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.6355]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.8207]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0008]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0023]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0983]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0007]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0011]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2233]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0007]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0035]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0038]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0052]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0003]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0043]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0047]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.7124]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0015]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0360]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0033]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0034]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0042]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0020]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0019]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0026]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0035]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0639]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0029]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0008]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0033]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0013]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0002]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0004]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0008]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0011]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0025]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0048]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0045]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0003]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0322]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0045]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0846]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0037]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1022]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1889]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0038]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0042]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0035]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0002]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0038]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0009]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0011]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0331]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0005]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0010]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0474]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0635]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0020]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0016]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0023]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0037]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0035]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0022]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0032]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0003]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# Accuracy: 0.9237536656891495
# Loss: 0.23138371978899996
# Epoch 4/10
#   0%|          | 0/107 [00:00<?, ?it/s]/raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# epoch: 4, train_loss:0.17738194: 100%|██████████| 107/107 [00:07<00:00, 13.75it/s]
# /raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# tran_Accuracy: 0.9228965112870126
# tensor([[0.0164]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0764]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0026]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0024]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0028]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1976]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0022]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0088]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0022]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0181]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0162]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0017]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0024]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.3664]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0232]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0057]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0112]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1147]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.5051]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.5884]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0027]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0019]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1424]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0015]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1006]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0036]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0121]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0089]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0037]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0029]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0020]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.4119]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0016]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0645]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0027]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0218]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0030]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0035]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0015]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0018]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0061]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1001]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0025]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0074]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0020]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0019]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0018]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0018]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0041]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0024]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0153]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0053]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0057]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2537]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0024]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0552]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.2970]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0018]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0025]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0025]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0025]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0016]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0105]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0015]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1102]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0970]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0032]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0018]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0103]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0161]], device='cuda:0') tensor([[[1.]]], device='cuda:0')
# tensor([[0.0076]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0030]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0014]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# Accuracy: 0.9149560117302052
# Loss: 0.18901879148492234
# Epoch 5/10
#   0%|          | 0/107 [00:00<?, ?it/s]/raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# epoch: 5, train_loss:0.16512980: 100%|██████████| 107/107 [00:07<00:00, 13.77it/s]
# /raid5/pangyj/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# tran_Accuracy: 0.924215772500733
# tensor([[0.0577]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.5019]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0276]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0013]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0103]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.3209]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0062]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.3146]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0066]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.1767]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0411]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0012]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0030]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# tensor([[0.0021]], device='cuda:0') tensor([[[0.]]], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-145-98a26807f96e> in <module>
#      60         print('tran_Accuracy: {}'.format(acc))
#      61         save_loss(10, epoch_loss)
# ---> 62         validation(model,criterion2,test_dataloaders,device)
#      63 # Save model
#      64 torch.save(model.state_dict(), 'weights10_%d.pth' % (epoch))
#
# <ipython-input-145-98a26807f96e> in validation(model, criterion, test_dataloaders, device)
#      13             step += 1
#      14             mask=mask.to(device)
# ---> 15             y = model(x.to(device))
#      16             if step%20==0:
#      17                 print(y.T,mask.T)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-140-60104401a172> in forward(self, x)
#     103         c13 = self.conv13(p12)
#     104         p13 = self.pool13(c13)
# --> 105         c14 = self.conv14(p13)
#     106         p14 = self.pool14(c14)
#     107         c15 = self.conv15(p14)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1163
#    1164     def __getattr__(self, name: str) -> Union[Tensor, 'Module']:
# -> 1165         if '_parameters' in self.__dict__:
#    1166             _parameters = self.__dict__['_parameters']
#    1167             if name in _parameters:
#
# KeyboardInterrupt:

# %%
# Out:
# Accuracy: 0.910850439882698
